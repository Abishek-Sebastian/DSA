// %%
#include <iostream>
using namespace std;

// %%
//a.
void a_fun1() { cout << "fun1 \n"; }

// %%
void a_fun2()
{
    cout << "Before fun1 \n";
    a_fun1();
    cout << "After fun1 \n";
}

// %%
cout << "Before fun2 \n";
a_fun2();
cout << "After fun2 \n";
// Out:
// Before fun2
// Before fun1
// fun1
// After fun1
// After fun2

// %%
//b.
void b_fun1()
{
    cout << "Abishek Sebastian";
    b_fun1();
}

// %%
// b_fun1(); Runs infinitely and shows kernel error

// %%
//c.
void c_fun1(int n)
{
    if(n==0)   // Base case -> Terminating condition
        return;
    cout << "Abishek Sebastian \n";
    c_fun1(n-1);
}

// %%
c_fun1(2);
// Out:
// Abishek Sebastian
// Abishek Sebastian
